# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
doma = pd.read_csv('doma.csv', sep=';')

# %%
restaurants = pd.read_excel('Restaurants.xlsx', sheet_name='data')

# %%
doma.head()
# Out:
#         id                 address  population  Longitude  Latitude
# 0  8649748   г. Москва, д. 9, к. 1         374   37.61764  55.75581
# 1  8963246  г. Москва, д. 42, к. 2        1232   37.61764  55.75581
# 2  8932138      г. Москва, д. 2301         244   37.61764  55.75581
# 3  8932139      г. Москва, д. 2302         244   37.61764  55.75581
# 4  8932140      г. Москва, д. 2303         244   37.61764  55.75581

# %%
restaurants.head()
# Out:
#    District                Name TypeObject  Longitude   Latitude  Рейтинг  \
# 0  Тверской            PastFood       кафе  37.577945  55.773926      4.2
# 1  Тверской              Newada        бар  37.577945  55.773926      4.9
# 2  Тверской     IKI Bar Kitchen       кафе  37.577945  55.773926      4.3
# 3  Тверской    Eleven Meathouse   ресторан  37.578990  55.774272      4.3
# 4  Тверской  Lola Pizza and Bar        бар  37.578990  55.774272      4.2
#
#    Отзывы          Y     Norm Y
# 0      10  29.012572  33.118352
# 1      38  40.389506  57.572571
# 2       6  27.506798  29.881755
# 3      78  38.536080  53.588713
# 4      89  38.193988  52.853400

# %%
#построю гистограммы

fig = plt.figure(figsize=(10.,8.))
_ = plt.hist(doma["population"], bins = 30, color = "black")

# %%
fig = plt.figure(figsize=(10.,8.))
_ = plt.hist(restaurants["Y"], bins = 30, color = "black")

# %%
from numpy import array, linspace
from sklearn.neighbors.kde import KernelDensity
from matplotlib.pyplot import plot

doma1 = np.array(doma["population"]).reshape(-1, 1)
kde = KernelDensity(kernel='cosine', bandwidth=10).fit(doma1)
s = linspace(0,50)
e = kde.score_samples(s.reshape(-1,1))
fig = plt.figure(figsize=(10., 5.))
_ = plot(s, e, color = "black")

# %%
restaurants1 = np.array(restaurants["Y"]).reshape(-1, 1)
kde = KernelDensity(kernel='tophat', bandwidth=1).fit(restaurants1)
s = linspace(0,50)
e = kde.score_samples(s.reshape(-1,1))
fig = plt.figure(figsize=(10.,5.))
_ = plot(s, e, color = "black")

# %%
#distplot () используется для визуализации параметрического распределения набора данных
import seaborn as sb
plt.figure(figsize=(10.,5.))
sb.distplot(doma1, kde=True)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(10.,5.))
sb.distplot(restaurants1, kde=True)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(20.,20.))
sb.distplot(restaurants1, kde=True)
sb.distplot(doma1, kde=True)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
